# %% [markdown]
# # 01_exploration

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carregando os dados

# %%
# Carregando dados
df = pd.read_csv('../data/raw/train.csv', parse_dates=['Date'])
# Out:
# C:\Users\heitor\AppData\Local\Temp\ipykernel_10148\2402060620.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/train.csv', parse_dates=['Date'])

# %%
# Visão geral
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Verificando valores nulos
df.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %% [markdown]
# ## Processamento

# %%
# Selecionando uma loja para análise inicial
store_id = 1
store_df = df[df['Store'] == store_id]

# Gráfico de vendas ao longo do tempo
plt.figure(figsize=(12, 4))
plt.plot(store_df['Date'], store_df['Sales'])
plt.title(f'Vendas da Loja {store_id} ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.grid()
plt.show()

# %%
# Estatísticas básicas
store_df['Sales'].describe()
# Out:
# count     942.000000
# mean     3945.704883
# std      2015.417840
# min         0.000000
# 25%      3588.250000
# 50%      4373.500000
# 75%      5220.000000
# max      9528.000000
# Name: Sales, dtype: float64
